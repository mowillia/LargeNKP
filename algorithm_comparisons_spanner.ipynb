# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from KP import KnapsackProblem

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

import time

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# <!-- - **Brute Force:**(`brute_force`) Involves listing all possible combinations of items, computing the total weights and total values of each combination and selecting the combination with the highest value with a weight below the stated limit.  -->
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# <!-- - **Fully Polynomial Time Approximate Solution (FPTAS):**(`fptas`)  Algorithm that is polynomial time in the number of elements and which has a tunable accuracy -->
#
# - **Greedy Algorithm:**(`greedy`)  Algorithm based on computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Exact $Z$ Algorithm:**(`exact_z_algorithm`) Algortihm based on computing the exact partition function recursively for a particular temperature
#
# - **Large W Algorithm ($T=0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T=0$
#
# - **Large W Algorithm ($T\neq0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T\neq0$

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %% [markdown]
# ### Hard Instance: Spanner Instance
#
# In [1], Pisinger identifies four additional difficult instances of the knapsack problem. One such instance is the "spanner instance"  constructed such that all items are multiples of a small set of items termed the "spanner set." To create the instance we first select $\nu$ weights in the interval $[1, R]$, and then define the corresponding values as $v_j = w_j + R/10$ (for the strongly correlated spanner instance). The $N$ items of the instance are found by randomly selecting an item from the $\nu$ items in the spanner set, and then a random multiplier $a$ from the interval $[1, m]$. The item then has the value and weight $(a v_j, aw_j)$.
#
# In what follows, we select $\nu=2$ and $m=10$ in accordance with Pisinger's results.  We will use this form of the knapsack problem to outline the performances of various algorithms including the algorithms outlined in the adjoining paper.
#
# [1] Pisinger, D. (2005). Where are the hard knapsack problems?. *Computers & Operations Research*, 32(9), 2271-2284.
#
# http://cic.tju.edu.cn/faculty/gongxj/course/algorithm/doc/2005-Wherearethehardknapsackproblems.pdf

# %%
# defining spanner instance

def v_spanner(nu, Nelems, m, R):

    """
    nu: number of elements in spanner set
    Nelems: number of elems for full list
    m: end point of multiplier range
    R: parameter for generating instances
    """

    w_spanner = np.random.randint(1,R+1,nu)
    v_spanner = w_spanner+R/10

    v, w = list(), list()
    idx_list = np.random.randint(0,nu, Nelems)
    for elem in idx_list:
        a = np.random.randint(1, m+1)
        v.append(int(a*v_spanner[elem]))
        w.append(int(a*w_spanner[elem]))

    return np.array(v), np.array(w)

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'DP': KP_test.knapsack01_dpV,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Exact Z': KP_test.exact_z_algorithm,
                  'Large W (T=0)': KP_test.largeW_algorithm,
                 'Large W (T/=0)': KP_test.largeW_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# DP
# Greedy
# Annealing
# Exact Z
# Large W (T=0)
# Large W (T/=0)

# %%
power = 12 # max power
R = 10**1

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
v_ratio_list_name_dict = defaultdict(lambda: list())
limit_list = list()
limit_sat_list_name_dict = defaultdict(lambda: list())

# list of gamma vals and min v/w 
gamma_list = list()
min_v_w_list = list()

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    value_vec, weight_vec = v_spanner(nu=2, Nelems=nelem, m=10, R=R)
    
    # Defining Weight Limit as the average of the weights of 
    # randomly chosen objects
    empt_list = []
    for _ in range(10):
        empt_list.append(np.dot(np.random.randint(0,2,nelem), weight_vec))
    Wlimit = int(np.mean(empt_list))   
    limit_list.append(Wlimit)
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Greedy': KP_init.greedy,
                        'Exact $Z$': KP_init.exact_z_algorithm,
                      'Annealing': KP_init.simann_knapsack,
                      r'Large $W$ ($T=0$)': KP_init.largeW_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeW_algorithm
                     }    
    
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('---')
        print('---')
              
    # collecting gamma_0 and min v/w values
    gamma_list.append(KP_init.gamma_calc())
    min_v_w_list.append(KP_init.greedy_ratio())
    if verbose:
        print('\n Computed gamma_0 value:',KP_init.gamma_calc())
        print('Computed min value-to-weight ratio:',KP_init.greedy_ratio(), '\n')    
    
    for name, algo in algo_name_dict.items():

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()
            
        time_list_name_dict[name].append(time.time()-start_clock)        
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)

        # adding accuracy 
        v_ratio_list_name_dict[name].append(np.dot(soln, value_vec)/true_value)  
        limit_sat_list_name_dict[name].append(np.dot(soln, weight_vec)<Wlimit)  
        
        if verbose: 
            print('%s 1- |V_soln-V_exact|/V_exact: %.7f' % (name, 1-np.abs(1-np.dot(soln, value_vec)/true_value)))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.7f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.7f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 184.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 181.000
# DP computation time: 0.0004690
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.8803828
# Greedy Weight: 158.000
# Greedy computation time: 0.0000160
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9952153
# Exact $Z$ Weight: 182.000
# Exact $Z$ computation time: 0.0088801
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9521531
# Annealing Weight: 173.000
# Annealing computation time: 0.0660930
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.1913876
# Large $W$ ($T=0$) Weight: 32.000
# Large $W$ ($T=0$) computation time: 0.0010412
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.1913876
# Large $W$ ($T\neq0$) Weight: 32.000
# Large $W$ ($T\neq0$) computation time: 0.0134151
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.0938659 sec
#
#
# ## N = 16
# ## Weight Limit: 251.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 251.000
# DP computation time: 0.0013080
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9966443
# Greedy Weight: 249.000
# Greedy computation time: 0.0000319
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 251.000
# Exact $Z$ computation time: 0.0257268
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9798658
# Annealing Weight: 251.000
# Annealing computation time: 0.0858369
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.4865772
# Large $W$ ($T=0$) Weight: 116.000
# Large $W$ ($T=0$) computation time: 0.0015540
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.4530201
# Large $W$ ($T\neq0$) Weight: 108.000
# Large $W$ ($T\neq0$) computation time: 0.0289559
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.2396190 sec
#
#
# ## N = 32
# ## Weight Limit: 521.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 521.000
# DP computation time: 0.0056849
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 521.000
# Greedy computation time: 0.0000522
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9952904
# Exact $Z$ Weight: 521.000
# Exact $Z$ computation time: 0.1358531
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9638932
# Annealing Weight: 517.000
# Annealing computation time: 0.0674989
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7613815
# Large $W$ ($T=0$) Weight: 388.000
# Large $W$ ($T=0$) computation time: 0.0012548
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6750392
# Large $W$ ($T\neq0$) Weight: 344.000
# Large $W$ ($T\neq0$) computation time: 0.0482781
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.5008550 sec
#
#
# ## N = 64
# ## Weight Limit: 1092.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1092.000
# DP computation time: 0.0245309
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9969834
# Greedy Weight: 1087.000
# Greedy computation time: 0.0001030
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 1092.000
# Exact $Z$ computation time: 0.5156753
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9683258
# Annealing Weight: 1092.000
# Annealing computation time: 0.0674510
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7013575
# Large $W$ ($T=0$) Weight: 744.000
# Large $W$ ($T=0$) computation time: 0.0010986
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6410256
# Large $W$ ($T\neq0$) Weight: 680.000
# Large $W$ ($T\neq0$) computation time: 0.1002800
# ---
# Done with Round #4!
# Total elapsed ime so far: 1.2127521 sec
#
#
# ## N = 128
# ## Weight Limit: 1782.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1781.000
# DP computation time: 0.0803530
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9986382
# Greedy Weight: 1778.000
# Greedy computation time: 0.0002122
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9940990
# Exact $Z$ Weight: 1782.000
# Exact $Z$ computation time: 1.7462370
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9677712
# Annealing Weight: 1780.000
# Annealing computation time: 0.0792329
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8896959
# Large $W$ ($T=0$) Weight: 1568.000
# Large $W$ ($T=0$) computation time: 0.0013061
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.7921017
# Large $W$ ($T\neq0$) Weight: 1396.000
# Large $W$ ($T\neq0$) computation time: 0.1812990
# ---
# Done with Round #5!
# Total elapsed ime so far: 3.3048859 sec
#
#
# ## N = 256
# ## Weight Limit: 3658.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 3658.000
# DP computation time: 0.3290770
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9986538
# Greedy Weight: 3652.000
# Greedy computation time: 0.0004029
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9961858
# Exact $Z$ Weight: 3657.000
# Exact $Z$ computation time: 6.8483551
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9703837
# Annealing Weight: 3658.000
# Annealing computation time: 0.0780709
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7258245
# Large $W$ ($T=0$) Weight: 2588.000
# Large $W$ ($T=0$) computation time: 0.0011127
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6181288
# Large $W$ ($T\neq0$) Weight: 2204.000
# Large $W$ ($T\neq0$) computation time: 0.4205909
# ---
# Done with Round #6!
# Total elapsed ime so far: 10.9878769 sec
#
#
# ## N = 512
# ## Weight Limit: 7406.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 7406.000
# DP computation time: 1.2697001
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9995610
# Greedy Weight: 7401.000
# Greedy computation time: 0.0007532
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9953907
# Exact $Z$ Weight: 7406.000
# Exact $Z$ computation time: 27.1865020
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9660887
# Annealing Weight: 7400.000
# Annealing computation time: 0.0879800
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8318701
# Large $W$ ($T=0$) Weight: 6064.000
# Large $W$ ($T=0$) computation time: 0.0016701
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.7484636
# Large $W$ ($T\neq0$) Weight: 5456.000
# Large $W$ ($T\neq0$) computation time: 0.6925719
# ---
# Done with Round #7!
# Total elapsed ime so far: 40.2327380 sec
#
#
# ## N = 1024
# ## Weight Limit: 15340.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 15340.000
# DP computation time: 5.3675330
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 15340.000
# Greedy computation time: 0.0015097
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9958324
# Exact $Z$ Weight: 15340.000
# Exact $Z$ computation time: 111.6489470
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9673007
# Annealing Weight: 15340.000
# Annealing computation time: 0.1037989
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7384056
# Large $W$ ($T=0$) Weight: 11056.000
# Large $W$ ($T=0$) computation time: 0.0018852
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6523830
# Large $W$ ($T\neq0$) Weight: 9768.000
# Large $W$ ($T\neq0$) computation time: 1.3663890
# ---
# Done with Round #8!
# Total elapsed ime so far: 158.7320759 sec
#
#
# ## N = 2048
# ## Weight Limit: 30510.000
# ---
# ---
#
#  Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 30510.000
# DP computation time: 21.1453829
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9999731
# Greedy Weight: 30508.000
# Greedy computation time: 0.0029380
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9963721
# Exact $Z$ Weight: 30510.000
# Exact $Z$ computation time: 457.5707140
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9687466
# Annealing Weight: 30509.000
# Annealing computation time: 0.1403227
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7351123
# Large $W$ ($T=0$) Weight: 21884.000
# Large $W$ ($T=0$) computation time: 0.0033541
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6531495
# Large $W$ ($T\neq0$) Weight: 19444.000
# Large $W$ ($T\neq0$) computation time: 2.6772311
# ---
# Done with Round #9!
# Total elapsed ime so far: 640.2876658 sec

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                    'DP': 's',  
                 'Greedy': 'o',
                 'Annealing': '^',
                r'Exact $Z$': 'h',
                r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                    'DP': 'blue',  
                 'Greedy': 'green',
                 'Annealing': 'darkorange' ,
                r'Exact $Z$': 'gold',
                r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'slategrey'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, v_ratio in v_ratio_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, 1-np.abs(1-np.array(v_ratio)), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22) 
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)


plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in v_ratio_list_name_dict.items():
    v_ratio = v_ratio_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]

    plt.plot([1-np.abs(1-v_ratio)], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45)
plt.yscale('log')
plt.xticks(fontsize = 22, rotation = -45)
plt.yticks(fontsize = 22)
plt.xlabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (0.25, 0.55), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_vratio_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ## Tabulated Results for $N = 2048$
#
# Here we tabulate the performance results for all algorithms applied to the spanner instance with N=2048 items.

# %%
# testing 
algo_name_list = ['DP','Greedy','Annealing', r'Exact $Z$', r'Large $W$ ($T=0$)', r'Large $W$ ($T\neq0$)']

# defining empty results dictionary
results_name_dict = {'runtime': ['runtime']+[0]*6,
                    'error': ['error']+[0]*6,}

# %%
for j in range(6):
    # name of algorithm
    name = algo_name_list[j]
    
    # calculating accuracy and runtime
    v_ratio_val, runtime = v_ratio_list_name_dict[name][-1], time_list_name_dict[name][-1]
    
    # filling in error and runtime values
    results_name_dict['error'][j+1] = np.abs(1-v_ratio_val)
    results_name_dict['runtime'][j+1] = runtime

# %%
from tabulate import tabulate
# creating table of results
tabular_results = []
for k, v in results_name_dict.items():
    tabular_results.append(v) 

print(tabulate(tabular_results, ["", "DP", "Greedy", "Annealing", "Exact Z", "T=0", "T/=0"], tablefmt="grid"))
# Out:
# +---------+---------+-------------+-------------+--------------+------------+---------+
# |         |      DP |      Greedy |   Annealing |      Exact Z |        T=0 |    T/=0 |
# +=========+=========+=============+=============+==============+============+=========+
# | runtime | 21.1454 | 0.00293803  |   0.140323  | 457.571      | 0.00335407 | 2.67723 |
# +---------+---------+-------------+-------------+--------------+------------+---------+
# | error   |  0      | 2.68731e-05 |   0.0312534 |   0.00362786 | 0.264888   | 0.34685 |
# +---------+---------+-------------+-------------+--------------+------------+---------+

# %% [markdown]
# ## Averag Normed Ratio Difference
#
# The normed ratio difference is defined as
#
# \begin{equation}
#     \text{norm. ratio diff.} = \frac{|\gamma_0 - v_\alpha/w_\alpha|}{\gamma_0},
#     \label{eq:ratio_diff}
# \end{equation}
#
# where $\gamma_0$ is determined from the zero-temperature algorithm and $v_{\alpha}/w_{\alpha}$ is the minimum ratio determined from the standard greedy algorithm. We compute the average of the normed ratio differences for all of the $N$ in the above plots.

# %%
# array conversion
gamma_array, min_v_w_array  = np.array(gamma_list), np.array(min_v_w_list)
# computing normed ratio difference
print('Average of Norm. Ratio. Diff: ', np.mean(np.abs(gamma_list - min_v_w_list)/gamma_list))
# Out:
# Average of Norm. Ratio. Diff:  0.0
