# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
from KP import KnapsackProblem

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

import time

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# <!-- - **Brute Force:**(`brute_force`) Involves listing all possible combinations of items, computing the total weights and total values of each combination and selecting the combination with the highest value with a weight below the stated limit.  -->
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# <!-- - **Fully Polynomial Time Approximate Solution (FPTAS):**(`fptas`)  Algorithm that is polynomial time in the number of elements and which has a tunable accuracy -->
#
# - **Greedy Algorithm:**(`greedy`)  Algorithm based on computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Exact $Z$ Algorithm:**(`exact_z_algorithm`) Algortihm based on computing the exact partition function recursively for a particular temperature
#
# - **Large W Algorithm ($T=0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T=0$
#
# - **Large W Algorithm ($T\neq0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T\neq0$

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %% [markdown]
# ### Hard Instance: Spanner Instance
#
# In [1], Pisinger identifies four additional difficult instances of the knapsack problem. One such instance is the "spanner instance"  constructed such that all items are multiples of a small set of items termed the "spanner set." To create the instance we first select $\nu$ weights in the interval $[1, R]$, and then define the corresponding values as $v_j = w_j + R/10$ (for the strongly correlated spanner instance). The $N$ items of the instance are found by randomly selecting an item from the $\nu$ items in the spanner set, and then a random multiplier $a$ from the interval $[1, m]$. The item then has the value and weight $(a v_j, aw_j)$.
#
# In what follows, we select $\nu=2$ and $m=10$ in accordance with Pisinger's results.  We will use this form of the knapsack problem to outline the performances of various algorithms including the algorithms outlined in the adjoining paper.
#
# [1] Pisinger, D. (2005). Where are the hard knapsack problems?. *Computers & Operations Research*, 32(9), 2271-2284.
#
# http://cic.tju.edu.cn/faculty/gongxj/course/algorithm/doc/2005-Wherearethehardknapsackproblems.pdf

# %%
# defining spanner instance

def v_spanner(nu, Nelems, m, R):

    """
    nu: number of elements in spanner set
    Nelems: number of elems for full list
    m: end point of multiplier range
    R: parameter for generating instances
    """

    w_spanner = np.random.randint(1,R+1,nu)
    v_spanner = w_spanner+R/10

    v, w = list(), list()
    idx_list = np.random.randint(0,nu, Nelems)
    for elem in idx_list:
        a = np.random.randint(1, m+1)
        v.append(int(a*v_spanner[elem]))
        w.append(int(a*w_spanner[elem]))

    return np.array(v), np.array(w)

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'DP': KP_test.knapsack01_dpV,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Exact Z': KP_test.exact_z_algorithm,
                  'Large W (T=0)': KP_test.largeW_algorithm,
                 'Large W (T/=0)': KP_test.largeW_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# DP
# Greedy
# Annealing
# Exact Z
# Large W (T=0)
# Large W (T/=0)

# %%
power = 13 # max power
R = 10

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
accuracy_list_name_dict = defaultdict(lambda: list())

# list of degeneracies
degeneracy_list = list()
correlation_list = list()
W_norm_list = list()

# list of gamma vals and min v/w 
gamma_list = list()
min_v_w_list = list()

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    value_vec, weight_vec = v_spanner(nu=5, Nelems=nelem, m=20, R=R)
    
    # Defining weight limit
    Wlimit = int(np.sum(weight_vec)/(2*np.sqrt(nelem)))   
    W_norm_list.append(Wlimit/np.mean(weight_vec))    
#     Wlimit = int(np.sum(weight_vec)/2)       
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Greedy': KP_init.greedy,
                      'Annealing': KP_init.simann_knapsack,
                      r'Exact $Z$': KP_init.exact_z_algorithm,
                      r'Large $W$ ($T=0$)': KP_init.largeW_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeW_algorithm
                     }    
    
    # degeneracy and correlation
    degeneracy_list.append(np.mean(list(Counter(weight_vec).values())))
    correlation_list.append(np.corrcoef(weight_vec, value_vec)[0,1])
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('## Weight Limit/Avg Weight: %.3f' % (Wlimit/np.mean(weight_vec)))
        
        # average number of copies of each item
#         print('## Average degeneracy: %.3f' % np.mean(list(Counter(weight_vec).values()))  )
        print('## N_eff: %.3f' % (nelem/np.mean(list(Counter(weight_vec).values()))) )        
        print('## Correlation between values and weights: %.3f' % np.corrcoef(weight_vec, value_vec)[0,1])
        print('---')
        print('---')
        
    # collecting gamma_0 and min v/w values
    gamma_list.append(KP_init.gamma_calc())
    min_v_w_list.append(KP_init.greedy_ratio())
    
    if verbose:
        print('\nComputed gamma_0 value:',KP_init.gamma_calc())
        print('Computed min value-to-weight ratio:',KP_init.greedy_ratio(), '\n')
              
    for name, algo in algo_name_dict.items():

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()      
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)
            
        # getting runtime and accuracy
        time_list_name_dict[name].append(time.time()-start_clock)     
        accuracy_list_name_dict[name].append(1-np.abs(1-np.dot(soln, value_vec)/true_value)) 
        
        if verbose: 
            print('%s 1- |V_soln-V_exact|/V_exact: %.7f' % (name, accuracy_list_name_dict[name][-1]))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.7f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.7f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 79.000
# ## Weight Limit/Avg Weight: 1.404
# ## N_eff: 7.000
# ## Correlation between values and weights: 0.999
# ---
# ---
#
# Computed gamma_0 value: 1.1428571428571428
# Computed min value-to-weight ratio: 1.1428571428571428
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 79.000
# DP computation time: 0.0002849
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 75.000
# Greedy computation time: 0.0000298
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 1.0000000
# Annealing Weight: 79.000
# Annealing computation time: 0.0927970
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 79.000
# Exact $Z$ computation time: 0.0019560
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9111111
# Large $W$ ($T=0$) Weight: 68.000
# Large $W$ ($T=0$) computation time: 0.0009389
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8000000
# Large $W$ ($T\neq0$) Weight: 60.000
# Large $W$ ($T\neq0$) computation time: 0.0146859
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.1170540 sec
#
#
# ## N = 16
# ## Weight Limit: 154.000
# ## Weight Limit/Avg Weight: 1.992
# ## N_eff: 15.000
# ## Correlation between values and weights: 0.997
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 152.000
# DP computation time: 0.0006232
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9736842
# Greedy Weight: 148.000
# Greedy computation time: 0.0000241
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.8526316
# Annealing Weight: 143.000
# Annealing computation time: 0.2224431
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 152.000
# Exact $Z$ computation time: 0.0087743
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0009389
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 0.0288589
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.3809500 sec
#
#
# ## N = 32
# ## Weight Limit: 174.000
# ## Weight Limit/Avg Weight: 2.824
# ## N_eff: 24.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.2000000000000002
# Computed min value-to-weight ratio: 1.2
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 174.000
# DP computation time: 0.0014877
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9485981
# Greedy Weight: 165.000
# Greedy computation time: 0.0000472
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9532710
# Annealing Weight: 171.000
# Annealing computation time: 0.1772859
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 174.000
# Exact $Z$ computation time: 0.0261078
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.6775701
# Large $W$ ($T=0$) Weight: 116.000
# Large $W$ ($T=0$) computation time: 0.0009630
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.3504673
# Large $W$ ($T\neq0$) Weight: 60.000
# Large $W$ ($T\neq0$) computation time: 0.0534527
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.6429272 sec
#
#
# ## N = 64
# ## Weight Limit: 216.000
# ## Weight Limit/Avg Weight: 3.986
# ## N_eff: 39.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 216.000
# DP computation time: 0.0040069
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9814815
# Greedy Weight: 212.000
# Greedy computation time: 0.0000918
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9296296
# Annealing Weight: 216.000
# Annealing computation time: 0.3127990
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9851852
# Exact $Z$ Weight: 213.000
# Exact $Z$ computation time: 0.0717089
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0009811
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 0.0969079
# ---
# Done with Round #4!
# Total elapsed ime so far: 1.1320210 sec
#
#
# ## N = 128
# ## Weight Limit: 347.000
# ## Weight Limit/Avg Weight: 5.651
# ## N_eff: 49.000
# ## Correlation between values and weights: 0.999
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 347.000
# DP computation time: 0.0133052
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9930716
# Greedy Weight: 344.000
# Greedy computation time: 0.0001769
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9330254
# Annealing Weight: 347.000
# Annealing computation time: 0.4312739
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9884527
# Exact $Z$ Weight: 347.000
# Exact $Z$ computation time: 0.2525742
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0013971
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 0.1873341
# ---
# Done with Round #5!
# Total elapsed ime so far: 2.0213299 sec
#
#
# ## N = 256
# ## Weight Limit: 515.000
# ## Weight Limit/Avg Weight: 7.992
# ## N_eff: 60.000
# ## Correlation between values and weights: 0.999
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 515.000
# DP computation time: 0.0405509
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9953344
# Greedy Weight: 512.000
# Greedy computation time: 0.0003850
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9253499
# Annealing Weight: 512.000
# Annealing computation time: 0.4703040
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9906687
# Exact $Z$ Weight: 515.000
# Exact $Z$ computation time: 0.8531051
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0013561
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 0.3785110
# ---
# Done with Round #6!
# Total elapsed ime so far: 3.7699780 sec
#
#
# ## N = 512
# ## Weight Limit: 704.000
# ## Weight Limit/Avg Weight: 11.301
# ## N_eff: 61.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 704.000
# DP computation time: 0.1154509
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 704.000
# Greedy computation time: 0.0007050
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9579545
# Annealing Weight: 703.000
# Annealing computation time: 1.1404417
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9954545
# Exact $Z$ Weight: 704.000
# Exact $Z$ computation time: 2.3921132
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0014930
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 0.8273931
# ---
# Done with Round #7!
# Total elapsed ime so far: 8.2530370 sec
#
#
# ## N = 1024
# ## Weight Limit: 1036.000
# ## Weight Limit/Avg Weight: 15.998
# ## N_eff: 61.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1036.000
# DP computation time: 0.3481700
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 1036.000
# Greedy computation time: 0.0013809
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9181467
# Annealing Weight: 1036.000
# Annealing computation time: 1.9965880
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9938224
# Exact $Z$ Weight: 1036.000
# Exact $Z$ computation time: 7.2721522
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0016398
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 1.3464861
# ---
# Done with Round #8!
# Total elapsed ime so far: 19.2279098 sec
#
#
# ## N = 2048
# ## Weight Limit: 1479.000
# ## Weight Limit/Avg Weight: 22.625
# ## N_eff: 61.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1479.000
# DP computation time: 1.0193131
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9983766
# Greedy Weight: 1476.000
# Greedy computation time: 0.0028489
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9226190
# Annealing Weight: 1478.000
# Annealing computation time: 2.9984601
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9880952
# Exact $Z$ Weight: 1477.000
# Exact $Z$ computation time: 21.1993520
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0021191
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 3.5450721
# ---
# Done with Round #9!
# Total elapsed ime so far: 48.0086939 sec
#
#
# ## N = 4096
# ## Weight Limit: 2121.000
# ## Weight Limit/Avg Weight: 31.986
# ## N_eff: 61.000
# ## Correlation between values and weights: 0.998
# ---
# ---
#
# Computed gamma_0 value: 1.25
# Computed min value-to-weight ratio: 1.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 2121.000
# DP computation time: 2.8513529
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9996228
# Greedy Weight: 2120.000
# Greedy computation time: 0.0056927
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9245568
# Annealing Weight: 2120.000
# Annealing computation time: 4.8683960
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9928329
# Exact $Z$ Weight: 2121.000
# Exact $Z$ computation time: 59.8773601
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T=0$) Weight: 0.000
# Large $W$ ($T=0$) computation time: 0.0031981
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.0000000
# Large $W$ ($T\neq0$) Weight: 0.000
# Large $W$ ($T\neq0$) computation time: 6.0856311
# ---
# Done with Round #10!
# Total elapsed ime so far: 121.7243199 sec

# %%
neff_unique = np.array(nelem_list)/np.array(degeneracy_list)
neff_unique
# Out:
# array([ 6., 12., 15., 19., 19., 19., 19., 19., 19., 19.])

# %%
np.array(correlation_list)
# Out:
# array([0.9878508 , 0.95709123, 0.94199583, 0.94730842, 0.94631408,
#        0.95338352, 0.94336934, 0.95042559, 0.94779133, 0.94827099])

# %%
plt.plot(nelem_list, neff_unique, color = 'salmon', markersize = 10, marker = 'o')

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xscale('log')
plt.xticks(fontsize = 15)
# plt.axhline(y=100, color = 'k', linestyle = 'dashed', linewidth = 0.25)
plt.yticks(fontsize = 15)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$N_{eff}$', fontsize = 24, labelpad=10.0)
plt.show()

# %%
plt.plot(nelem_list, np.array(W_norm_list), markersize = 10, marker = 'o')

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xscale('log')
plt.xticks(fontsize = 15)
# plt.axhline(y=100, color = 'k', linestyle = 'dashed', linewidth = 0.25)
plt.yticks(fontsize = 15)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$W/\bar{w}$', fontsize = 24, labelpad=10.0)
plt.show()

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                    'DP': 's',  
                 'Greedy': 'o',
                 'Annealing': '^',
                r'Exact $Z$': 'h',
                r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                    'DP': 'blue',  
                 'Greedy': 'green',
                 'Annealing': 'darkorange' ,
                r'Exact $Z$': 'gold',
                r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'slategrey'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, accuracy_ in accuracy_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(accuracy_), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22) 
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, accuracy_ in accuracy_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(accuracy_), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22) 
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)


plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in accuracy_list_name_dict.items():
    accuracy_ = accuracy_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]

    plt.plot([accuracy_], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45)
plt.yscale('log')
plt.xticks(fontsize = 22, rotation = -45)
plt.yticks(fontsize = 22)
plt.xlabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (0.25, 0.55), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_vratio_spanner.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ## Tabulated Results for $N = 2048$
#
# Here we tabulate the performance results for all algorithms applied to the spanner instance with N=2048 items.

# %%
# testing 
algo_name_list = ['DP','Greedy','Annealing', r'Exact $Z$', r'Large $W$ ($T=0$)', r'Large $W$ ($T\neq0$)']

# defining empty results dictionary
results_name_dict = {'runtime': ['runtime']+[0]*6,
                    'error': ['error']+[0]*6,}

# %%
for j in range(6):
    # name of algorithm
    name = algo_name_list[j]
    
    # calculating accuracy and runtime
    accuracy, runtime = accuracy_list_name_dict[name][-1], time_list_name_dict[name][-1]
    
    # filling in error and runtime values
    results_name_dict['error'][j+1] = 1-accuracy
    results_name_dict['runtime'][j+1] = runtime

# %%
from tabulate import tabulate
# creating table of results
tabular_results = []
for k, v in results_name_dict.items():
    tabular_results.append(v) 

print(tabulate(tabular_results, ["", "DP", "Greedy", "Annealing", "Exact Z", "T=0", "T/=0"], tablefmt="grid"))
# Out:
# +---------+---------+-------------+-------------+--------------+------------+---------+
# |         |      DP |      Greedy |   Annealing |      Exact Z |        T=0 |    T/=0 |
# +=========+=========+=============+=============+==============+============+=========+
# | runtime | 21.1454 | 0.00293803  |   0.140323  | 457.571      | 0.00335407 | 2.67723 |
# +---------+---------+-------------+-------------+--------------+------------+---------+
# | error   |  0      | 2.68731e-05 |   0.0312534 |   0.00362786 | 0.264888   | 0.34685 |
# +---------+---------+-------------+-------------+--------------+------------+---------+

# %% [markdown]
# ## Averag Normed Ratio Difference
#
# The normed ratio difference is defined as
#
# \begin{equation}
#     \text{norm. ratio diff.} = \frac{|\gamma_0 - v_\alpha/w_\alpha|}{\gamma_0},
#     \label{eq:ratio_diff}
# \end{equation}
#
# where $\gamma_0$ is determined from the zero-temperature algorithm and $v_{\alpha}/w_{\alpha}$ is the minimum ratio determined from the standard greedy algorithm. We compute the average of the normed ratio differences for all of the $N$ in the above plots.

# %%
# array conversion
gamma_array, min_v_w_array  = np.array(gamma_list), np.array(min_v_w_list)
# computing normed ratio difference
print('Average of Norm. Ratio. Diff: ', np.mean(np.abs(gamma_list - min_v_w_list)/gamma_list))
# Out:
# Average of Norm. Ratio. Diff:  0.0
