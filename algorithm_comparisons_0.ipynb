# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from collections import defaultdict
import logging
from sklearn.metrics import accuracy_score
from KP import KnapsackProblem

# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "serif",
#     "font.serif": ["Computer Modern Roman"],
# })

import math
import time

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# - **Brute Force:**(`brute_force`) Involves listing all possible combinations of items, computing the total weights and total values of each combination and selecting the combination with the highest value with a weight below the stated limit.
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# - **Fully Polynomial Time Approximate Solution (FPTAS):**(`fptas`)  Algorithm that is polynomial time in the number of elements and which has a tunable accuracy
#
# - **Greedy Algorithm:**(`greedy`)  Involves computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Large N Algorithm:**(`zero_one_algorithm`)  Algorithm based on statistical physics representation of the system

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'Brute': KP_test.brute_force,
                  'DP': KP_test.knapsack01_dpV,
                  'FPTAS': KP_test.fptas,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Large W (T=0)': KP_test.largeN_algorithm,
                 'Large W (T/=0)': KP_test.largeN_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# Brute
# DP
# FPTAS
# Greedy
# Annealing
# Large W (T=0)
# Large W (T/=0)

# %%
# max power
power = 11

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
v_ratio_list_name_dict = defaultdict(lambda: list())
limit_list = list()
limit_sat_list_name_dict = defaultdict(lambda: list())

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    weight_vec = np.random.randint(1,100,nelem)
    value_vec = np.random.randint(1,100,nelem)
    
    # Defining Weight Limit as the average of the weights of 
    # randomly chosen objects
    empt_list = []
    for _ in range(10):
        empt_list.append(np.dot(np.random.randint(0,2,nelem), weight_vec))
    Wlimit = int(np.mean(empt_list))   
    limit_list.append(Wlimit)
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Brute': KP_init.brute_force,
                      'FPTAS': KP_init.fptas,
                      'Greedy': KP_init.greedy,
                      'Annealing': KP_init.simann_knapsack,
                      r'Large $W$ ($T=0$)': KP_init.largeN_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeN_algorithm
                     }    
    
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('---')
        print('---')
              
    
    for name, algo in algo_name_dict.items():
        # don't run brute force for elements greater than 23
        if nelem > 16 and name == 'Brute':
            continue

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()
            
        time_list_name_dict[name].append(time.time()-start_clock)        
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)

        # adding accuracy 
        v_ratio_list_name_dict[name].append(np.dot(soln, value_vec)/true_value)  
        limit_sat_list_name_dict[name].append(np.dot(soln, weight_vec)<Wlimit)  
        
        if verbose: 
            print('%s V_soln/V_exact: %.3f' % (name, np.dot(soln, value_vec)/true_value))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.3f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.3f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 287.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 264.000
# DP computation time: 0.002
# ---
# Brute V_soln/V_exact: 1.000
# Brute Weight: 264.000
# Brute computation time: 0.001
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 264.000
# FPTAS computation time: 0.000
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 264.000
# Greedy computation time: 0.000
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.837
# Annealing Weight: 284.000
# Annealing computation time: 0.086
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 1.000
# Large $W$ ($T=0$) Weight: 264.000
# Large $W$ ($T=0$) computation time: 0.030
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 1.000
# Large $W$ ($T\neq0$) Weight: 264.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.122 sec
#
#
# ## N = 16
# ## Weight Limit: 416.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 403.000
# DP computation time: 0.002
# ---
# Brute V_soln/V_exact: 1.000
# Brute Weight: 403.000
# Brute computation time: 0.206
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 403.000
# FPTAS computation time: 0.002
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 403.000
# Greedy computation time: 0.000
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.801
# Annealing Weight: 376.000
# Annealing computation time: 0.062
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 1.000
# Large $W$ ($T=0$) Weight: 403.000
# Large $W$ ($T=0$) computation time: 0.054
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 1.000
# Large $W$ ($T\neq0$) Weight: 403.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.449 sec
#
#
# ## N = 32
# ## Weight Limit: 850.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 843.000
# DP computation time: 0.009
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 843.000
# FPTAS computation time: 0.010
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 843.000
# Greedy computation time: 0.000
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.938
# Annealing Weight: 844.000
# Annealing computation time: 0.063
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 0.985
# Large $W$ ($T=0$) Weight: 813.000
# Large $W$ ($T=0$) computation time: 0.087
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.985
# Large $W$ ($T\neq0$) Weight: 813.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.619 sec
#
#
# ## N = 64
# ## Weight Limit: 1643.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 1636.000
# DP computation time: 0.035
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 1636.000
# FPTAS computation time: 0.077
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 1636.000
# Greedy computation time: 0.000
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.847
# Annealing Weight: 1637.000
# Annealing computation time: 0.064
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 0.994
# Large $W$ ($T=0$) Weight: 1603.000
# Large $W$ ($T=0$) computation time: 0.185
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.994
# Large $W$ ($T\neq0$) Weight: 1603.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #4!
# Total elapsed ime so far: 0.981 sec
#
#
# ## N = 128
# ## Weight Limit: 3049.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 3047.000
# DP computation time: 0.130
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 3047.000
# FPTAS computation time: 0.613
# ---
# Greedy V_soln/V_exact: 0.997
# Greedy Weight: 3028.000
# Greedy computation time: 0.000
# ---
# Annealing V_soln/V_exact: 0.840
# Annealing Weight: 3034.000
# Annealing computation time: 0.070
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 0.997
# Large $W$ ($T=0$) Weight: 3028.000
# Large $W$ ($T=0$) computation time: 0.320
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.989
# Large $W$ ($T\neq0$) Weight: 2974.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #5!
# Total elapsed ime so far: 2.116 sec
#
#
# ## N = 256
# ## Weight Limit: 6307.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 6307.000
# DP computation time: 0.552
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 6307.000
# FPTAS computation time: 4.566
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 6300.000
# Greedy computation time: 0.000
# ---
# Annealing V_soln/V_exact: 0.772
# Annealing Weight: 6303.000
# Annealing computation time: 0.076
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 1.000
# Large $W$ ($T=0$) Weight: 6297.000
# Large $W$ ($T=0$) computation time: 0.659
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.991
# Large $W$ ($T\neq0$) Weight: 6172.000
# Large $W$ ($T\neq0$) computation time: 0.001
# ---
# Done with Round #6!
# Total elapsed ime so far: 7.972 sec
#
#
# ## N = 512
# ## Weight Limit: 12681.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 12681.000
# DP computation time: 2.197
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 12680.000
# FPTAS computation time: 37.188
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 12680.000
# Greedy computation time: 0.001
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.774
# Annealing Weight: 12680.000
# Annealing computation time: 0.085
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 0.999
# Large $W$ ($T=0$) Weight: 12642.000
# Large $W$ ($T=0$) computation time: 1.206
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.986
# Large $W$ ($T\neq0$) Weight: 12306.000
# Large $W$ ($T\neq0$) computation time: 0.002
# ---
# Done with Round #7!
# Total elapsed ime so far: 48.651 sec
#
#
# ## N = 1024
# ## Weight Limit: 25521.000
# ---
# ---
# DP V_soln/V_exact: 1.000
# DP Weight: 25521.000
# DP computation time: 8.837
# ---
# FPTAS V_soln/V_exact: 1.000
# FPTAS Weight: 25521.000
# FPTAS computation time: 316.115
# ---
# Greedy V_soln/V_exact: 1.000
# Greedy Weight: 25519.000
# Greedy computation time: 0.002
# ---
# Stopping annealing because error tolerance was reached
# Annealing V_soln/V_exact: 0.757
# Annealing Weight: 25519.000
# Annealing computation time: 0.101
# ---
# Large $W$ ($T=0$) V_soln/V_exact: 1.000
# Large $W$ ($T=0$) Weight: 25504.000
# Large $W$ ($T=0$) computation time: 2.999
# ---
# Large $W$ ($T\neq0$) V_soln/V_exact: 0.992
# Large $W$ ($T\neq0$) Weight: 25073.000
# Large $W$ ($T\neq0$) computation time: 0.003
# ---
# Done with Round #8!
# Total elapsed ime so far: 376.709 sec

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                  'Brute': 'D',  
                    'DP': 's',  
                    'FPTAS': 'X',
                 'Greedy': 'o',
                 'Annealing': '^',
                 r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                  'Brute': 'slategrey',  
                    'DP': 'purple',  
                    'FPTAS': 'blue',
                 'Greedy': 'green',
                 'Annealing': 'darkorange',
                 r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'black'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, v_ratio in v_ratio_list_name_dict.items():
    if name == 'Brute':
        nums = [8, 16]
        
        plt.plot(nums, v_ratio, marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-',  markersize = 15, label = name)
    else:
        nums = nelem_list
        plt.plot(nums, v_ratio, marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label =  name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.ylabel(r'$V/V_{exact}$', fontsize = 24)
plt.legend(loc = 'best', fontsize = 16)

plt.ylim([.5, 1.05])

plt.show()

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, v_ratio in v_ratio_list_name_dict.items():
    if name == 'Brute':
        nums = [8, 16]
        
        plt.plot(nums, v_ratio, marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-',  markersize = 15, label = r'%s' % name)
    else:
        nums = nelem_list
        plt.plot(nums, v_ratio, marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.ylabel(r'$V/V_{exact}$', fontsize = 24)
plt.legend(loc = 'best', fontsize = 13)

plt.ylim([.5, 1.05])

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_Scientific_reports/vratio_vs_num_easykp_new.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():
    if name == 'Brute':
        nums = [8, 16]
        
        plt.loglog(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-',  markersize = 15, label = r'%s' % name)
    else:
        nums = nelem_list
        plt.loglog(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)


plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (.01,.6), fontsize = 13)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_Scientific_reports/time_vs_num_easykp_new.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Rate vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in v_ratio_list_name_dict.items():
    v_ratio = v_ratio_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]
    if name == 'Brute':
        continue
    else:

        plt.plot([v_ratio], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.grid(alpha = 0.45)
plt.xlabel(r'$V/V_{exact}$', fontsize = 24)
plt.yscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc ='best', fontsize = 13)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_Scientific_reports/time_vs_vratio_easykp_new.png', dpi = 100, bbox_inches='tight' )

plt.show()
