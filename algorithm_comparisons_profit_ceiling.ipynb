# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from KP import KnapsackProblem

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

import time

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# - **Greedy Algorithm:**(`greedy`)  Algorithm based on computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Exact $Z$ Algorithm:**(`exact_z_algorithm`) Algortihm based on computing the exact partition function recursively for a particular temperature
#
# - **Large W Algorithm ($T=0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T=0$
#
# - **Large W Algorithm ($T\neq0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T\neq0$

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %% [markdown]
# ### Hard Instance: Profit-Ceiling Instance
#
# In [1], Pisinger identifies four additional difficult instances of the knapsack problem. One such instance is the "profit-ceiling instance" whose main property is that all values are multiples of a given paramater $d$. The instance is generated by randomly (and uniformly) selecting weights in the interval $[1,R]$ and then setting the values to $p_j = d \lceil w_j/ d\rceil$.
#
# Pisinger notes that particularly difficult instancs appeared by choosing $d=3$. We will use this form of the knapsack problem to outline the performances of various algorithms including the algorithms outlined in the adjoining paper.
#
# [1] Pisinger, D. (2005). Where are the hard knapsack problems?. *Computers & Operations Research*, 32(9), 2271-2284.

# %%
# defining profit ceiling instance
v_ceiling = lambda w, d: np.array([d*int(np.ceil(welem/d)) for welem in w])

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'DP': KP_test.knapsack01_dpV,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Exact Z': KP_test.exact_z_algorithm,
                  'Large W (T=0)': KP_test.largeW_algorithm,
                 'Large W (T/=0)': KP_test.largeW_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# DP
# Greedy
# Annealing
# Exact Z
# Large W (T=0)
# Large W (T/=0)

# %%
power = 12 # max power
R = 10**2 
d = 3

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
v_ratio_list_name_dict = defaultdict(lambda: list())
limit_list = list()
limit_sat_list_name_dict = defaultdict(lambda: list())

# list of gamma vals and min v/w 
gamma_list = list()
min_v_w_list = list()

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    weight_vec = np.random.randint(1,R+1,nelem)
    value_vec = v_ceiling(weight_vec, d=d)
    
    # Defining Weight Limit as the average of the weights of 
    # randomly chosen objects
    empt_list = []
    for _ in range(10):
        empt_list.append(np.dot(np.random.randint(0,2,nelem), weight_vec))
    Wlimit = int(np.mean(empt_list))   
    limit_list.append(Wlimit)
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Greedy': KP_init.greedy,
                      'Annealing': KP_init.simann_knapsack,
                      r'Exact $Z$': KP_init.exact_z_algorithm,
                      r'Large $W$ ($T=0$)': KP_init.largeW_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeW_algorithm
                     }    
    
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('---')
        print('---')
              
    # collecting gamma_0 and min v/w values
    gamma_list.append(KP_init.gamma_calc())
    min_v_w_list.append(KP_init.greedy_ratio())
    if verbose:
        print('\nComputed gamma_0 value:',KP_init.gamma_calc())
        print('Computed min value-to-weight ratio:',KP_init.greedy_ratio(), '\n')    
    
    for name, algo in algo_name_dict.items():

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()
            
        time_list_name_dict[name].append(time.time()-start_clock)        
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)

        # adding accuracy 
        v_ratio_list_name_dict[name].append(np.dot(soln, value_vec)/true_value)  
        limit_sat_list_name_dict[name].append(np.dot(soln, weight_vec)<Wlimit)  
        
        if verbose: 
            print('%s 1- |V_soln-V_exact|/V_exact: %.7f' % (name, 1-np.abs(1-np.dot(soln, value_vec)/true_value)))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.7f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.7f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 269.000
# ---
# ---
#
# Computed gamma_0 value: 1.0
# Computed min value-to-weight ratio: 1.0
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 268.000
# DP computation time: 0.0007002
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.8681319
# Greedy Weight: 232.000
# Greedy computation time: 0.0000172
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9560440
# Annealing Weight: 258.000
# Annealing computation time: 0.0624919
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 268.000
# Exact $Z$ computation time: 0.0123131
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.7362637
# Large $W$ ($T=0$) Weight: 196.000
# Large $W$ ($T=0$) computation time: 0.0009532
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.4285714
# Large $W$ ($T\neq0$) Weight: 113.000
# Large $W$ ($T\neq0$) computation time: 0.0168250
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.0978119 sec
#
#
# ## N = 16
# ## Weight Limit: 523.000
# ---
# ---
#
# Computed gamma_0 value: 1.0
# Computed min value-to-weight ratio: 1.0
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 523.000
# DP computation time: 0.0026393
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 522.000
# Greedy computation time: 0.0000262
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9382022
# Annealing Weight: 493.000
# Annealing computation time: 0.0598078
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9943820
# Exact $Z$ Weight: 520.000
# Exact $Z$ computation time: 0.0524950
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8820225
# Large $W$ ($T=0$) Weight: 459.000
# Large $W$ ($T=0$) computation time: 0.0015180
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6235955
# Large $W$ ($T\neq0$) Weight: 323.000
# Large $W$ ($T\neq0$) computation time: 0.0268621
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.2434409 sec
#
#
# ## N = 32
# ## Weight Limit: 882.000
# ---
# ---
#
# Computed gamma_0 value: 1.0169491525423728
# Computed min value-to-weight ratio: 1.0169491525423728
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 882.000
# DP computation time: 0.0093291
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 881.000
# Greedy computation time: 0.0000482
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9900990
# Annealing Weight: 882.000
# Annealing computation time: 0.0657530
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9933993
# Exact $Z$ Weight: 879.000
# Exact $Z$ computation time: 0.2043824
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9834983
# Large $W$ ($T=0$) Weight: 866.000
# Large $W$ ($T=0$) computation time: 0.0012712
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.3036304
# Large $W$ ($T\neq0$) Weight: 264.000
# Large $W$ ($T\neq0$) computation time: 0.0503161
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.5776970 sec
#
#
# ## N = 64
# ## Weight Limit: 1720.000
# ---
# ---
#
# Computed gamma_0 value: 1.01123595505618
# Computed min value-to-weight ratio: 1.0112359550561798
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1720.000
# DP computation time: 0.0372841
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9966102
# Greedy Weight: 1714.000
# Greedy computation time: 0.0001080
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9881356
# Annealing Weight: 1719.000
# Annealing computation time: 0.0693409
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9966102
# Exact $Z$ Weight: 1720.000
# Exact $Z$ computation time: 0.7971210
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9932203
# Large $W$ ($T=0$) Weight: 1708.000
# Large $W$ ($T=0$) computation time: 0.0018649
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.3135593
# Large $W$ ($T\neq0$) Weight: 531.000
# Large $W$ ($T\neq0$) computation time: 0.0971200
# ---
# Done with Round #4!
# Total elapsed ime so far: 1.5835900 sec
#
#
# ## N = 128
# ## Weight Limit: 3181.000
# ---
# ---
#
# Computed gamma_0 value: 1.0120481927710845
# Computed min value-to-weight ratio: 1.0120481927710843
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 3181.000
# DP computation time: 0.1410670
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 3180.000
# Greedy computation time: 0.0002129
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9871912
# Annealing Weight: 3179.000
# Annealing computation time: 0.0747728
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9945105
# Exact $Z$ Weight: 3181.000
# Exact $Z$ computation time: 2.9620922
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9954254
# Large $W$ ($T=0$) Weight: 3165.000
# Large $W$ ($T=0$) computation time: 0.0013218
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.1866423
# Large $W$ ($T\neq0$) Weight: 576.000
# Large $W$ ($T\neq0$) computation time: 0.1886621
# ---
# Done with Round #5!
# Total elapsed ime so far: 4.9550958 sec
#
#
# ## N = 256
# ## Weight Limit: 6376.000
# ---
# ---
#
# Computed gamma_0 value: 1.0135135135135136
# Computed min value-to-weight ratio: 1.0135135135135136
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 6376.000
# DP computation time: 0.5481400
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 6376.000
# Greedy computation time: 0.0004010
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9849521
# Annealing Weight: 6367.000
# Annealing computation time: 0.0771761
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9940720
# Exact $Z$ Weight: 6376.000
# Exact $Z$ computation time: 12.0477979
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9949840
# Large $W$ ($T=0$) Weight: 6343.000
# Large $W$ ($T=0$) computation time: 0.0013931
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.1837665
# Large $W$ ($T\neq0$) Weight: 1135.000
# Large $W$ ($T\neq0$) computation time: 0.3634949
# ---
# Done with Round #6!
# Total elapsed ime so far: 17.9976521 sec
#
#
# ## N = 512
# ## Weight Limit: 12638.000
# ---
# ---
#
# Computed gamma_0 value: 1.0116279069767442
# Computed min value-to-weight ratio: 1.0116279069767442
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 12638.000
# DP computation time: 2.2277896
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 12638.000
# Greedy computation time: 0.0007980
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9839228
# Annealing Weight: 12638.000
# Annealing computation time: 0.0904822
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9951768
# Exact $Z$ Weight: 12638.000
# Exact $Z$ computation time: 46.8382609
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9703721
# Large $W$ ($T=0$) Weight: 12255.000
# Large $W$ ($T=0$) computation time: 0.0014870
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.2758383
# Large $W$ ($T\neq0$) Weight: 3401.000
# Large $W$ ($T\neq0$) computation time: 0.6349852
# ---
# Done with Round #7!
# Total elapsed ime so far: 67.7971730 sec
#
#
# ## N = 1024
# ## Weight Limit: 25525.000
# ---
# ---
#
# Computed gamma_0 value: 1.0120481927710845
# Computed min value-to-weight ratio: 1.0120481927710843
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 25525.000
# DP computation time: 8.8798060
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 25524.000
# Greedy computation time: 0.0015440
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9839827
# Annealing Weight: 25525.000
# Annealing computation time: 0.1093159
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9945473
# Exact $Z$ Weight: 25525.000
# Exact $Z$ computation time: 192.8577180
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9947745
# Large $W$ ($T=0$) Weight: 25387.000
# Large $W$ ($T=0$) computation time: 0.0020521
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.2688856
# Large $W$ ($T\neq0$) Weight: 6681.000
# Large $W$ ($T\neq0$) computation time: 1.5008819
# ---
# Done with Round #8!
# Total elapsed ime so far: 271.1566410 sec
#
#
# ## N = 2048
# ## Weight Limit: 51045.000
# ---
# ---
#
# Computed gamma_0 value: 1.012987012987013
# Computed min value-to-weight ratio: 1.0129870129870129
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 51045.000
# DP computation time: 35.7599678
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 51045.000
# Greedy computation time: 0.0029838
# ---
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9852348
# Annealing Weight: 51041.000
# Annealing computation time: 0.1367052
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9943211
# Exact $Z$ Weight: 51045.000
# Exact $Z$ computation time: 829.6030838
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9935260
# Large $W$ ($T=0$) Weight: 50707.000
# Large $W$ ($T=0$) computation time: 0.0031531
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.2377193
# Large $W$ ($T\neq0$) Weight: 11786.000
# Large $W$ ($T\neq0$) computation time: 2.9519968
# ---
# Done with Round #9!
# Total elapsed ime so far: 1139.6289837 sec

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                    'DP': 's',  
                 'Greedy': 'o',
                 'Annealing': '^',
                r'Exact $Z$': 'h',
                r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                    'DP': 'blue',  
                 'Greedy': 'green',
                 'Annealing': 'darkorange' ,
                r'Exact $Z$': 'gold',
                r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'slategrey'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, v_ratio in v_ratio_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, 1-np.abs(1-np.array(v_ratio)), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)
plt.legend(loc = 'best', fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_profit_ceiling.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)


plt.grid(alpha = 0.45)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_profit_ceiling.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in v_ratio_list_name_dict.items():
    v_ratio = v_ratio_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]

    plt.plot([1-np.abs(1-v_ratio)], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45)
plt.yscale('log')
plt.xticks(fontsize = 22, rotation = -45)
plt.yticks(fontsize = 22)
plt.xlabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (0.4, 0.5), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_vratio_profit_ceiling.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ## Tabulated Results for $N = 2048$
#
# Here we tabulate the performance results for all algorithms applied to the profit-ceiling instance with N=2048 items.

# %%
# testing 
algo_name_list = ['DP','Greedy','Annealing', r'Exact $Z$', r'Large $W$ ($T=0$)', r'Large $W$ ($T\neq0$)']

# defining empty results dictionary
results_name_dict = {'runtime': ['runtime']+[0]*6,
                    'error': ['error']+[0]*6,}

# %%
for j in range(6):
    # name of algorithm
    name = algo_name_list[j]
    
    # calculating accuracy and runtime
    v_ratio_val, runtime = v_ratio_list_name_dict[name][-1], time_list_name_dict[name][-1]
    
    # filling in error and runtime values
    results_name_dict['error'][j+1] = np.abs(1-v_ratio_val)
    results_name_dict['runtime'][j+1] = runtime

# %%
from tabulate import tabulate
# creating table of results
tabular_results = []
for k, v in results_name_dict.items():
    tabular_results.append(v) 

print(tabulate(tabular_results, ["", "DP", "Greedy", "Annealing", "Exact Z", "T=0", "T/=0"], tablefmt="grid"))
# Out:
# +---------+-------+------------+-------------+--------------+------------+----------+
# |         |    DP |     Greedy |   Annealing |      Exact Z |        T=0 |     T/=0 |
# +=========+=======+============+=============+==============+============+==========+
# | runtime | 35.76 | 0.00298381 |   0.136705  | 829.603      | 0.00315309 | 2.952    |
# +---------+-------+------------+-------------+--------------+------------+----------+
# | error   |  0    | 0          |   0.0147652 |   0.00567891 | 0.00647396 | 0.762281 |
# +---------+-------+------------+-------------+--------------+------------+----------+

# %% [markdown]
# ## Averag Normed Ratio Difference
#
# The normed ratio difference is defined as
#
# \begin{equation}
#     \text{norm. ratio diff.} = \frac{|\gamma_0 - v_\alpha/w_\alpha|}{\gamma_0},
#     \label{eq:ratio_diff}
# \end{equation}
#
# where $\gamma_0$ is determined from the zero-temperature algorithm and $v_{\alpha}/w_{\alpha}$ is the minimum ratio determined from the standard greedy algorithm. We compute the average of the normed ratio differences for all of the $N$ in the above plots.

# %%
# array conversion
gamma_array, min_v_w_array  = np.array(gamma_list), np.array(min_v_w_list)
# computing normed ratio difference
print('Average of Norm. Ratio. Diff: ', np.mean(np.abs(gamma_list - min_v_w_list)/gamma_list))
# Out:
# Average of Norm. Ratio. Diff:  9.75086394901416e-17
