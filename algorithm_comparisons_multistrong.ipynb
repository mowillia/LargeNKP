# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from KP import KnapsackProblem

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

import time

# %%
import mpmath as mp
mp.dps = 30; mp.pretty = True

# defining exponential for high precision calcs
mp_exp_array = np.frompyfunc(mp.exp, 1, 1)

# %%
float(mp_exp_array(5))
# Out:
# 148.4131591025766

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# - **Greedy Algorithm:**(`greedy`)  Algorithm based on computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Exact $Z$ Algorithm:**(`exact_z_algorithm`) Algortihm based on computing the exact partition function recursively for a particular temperature
#
# - **Large W Algorithm ($T=0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T=0$
#
# - **Large W Algorithm ($T\neq0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T\neq0$

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %% [markdown]
# ### Hard Instance: Multiple Strongly Correlated Instance
#
# In [1], Pisinger identifies hard four additional difficult instances of the knapsack problem. One such instance is the "multiply strongly correlated instance"  consisting of a combination of two sets of strongly correlated instances. The instnaces that have values that are related to weights through $v = w + k_i$ where $k_i$ for $i=1, 2$ is different for each instance.
#
# In particular the instances are generated as follows: The weights of $N$ items are randomly distributed in $[1, R]$. If the weight $w_j$ is divisible by a chosen $d$, we set the value $v_j = w_j + k_1$, otherwise we set it to $v_j = w_j + k_2$.
#
# Pisinger chose the values $d=6$, $k_1 = 3R/10$, and $k_2 = 2R/10$.  We will use this form of the knapsack problem to outline the performances of various algorithms including the algorithms outlined in the adjoining paper.
#
# [1] Pisinger, D. (2005). Where are the hard knapsack problems?. *Computers & Operations Research*, 32(9), 2271-2284.
#
# http://cic.tju.edu.cn/faculty/gongxj/course/algorithm/doc/2005-Wherearethehardknapsackproblems.pdf

# %%
# defining multi strong instance

def v_multistrong(w, R, d):

    """
    w: list of weights
    m: end point of multiplier range
    R: parameter for generating instances
    d: divisor to determine which strongly correlated factor to choose
    """

    k1, k2 = 3*R/10, 2*R/10

    v = list()
    for welem in w:
        if welem % d == 0:
            v.append(int(welem + k1))
        else:
            v.append(int(welem+k2))
            
    return np.array(v)

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'DP': KP_test.knapsack01_dpV,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Exact Z': KP_test.exact_z_algorithm,
                  'Large W (T=0)': KP_test.largeW_algorithm,
                 'Large W (T/=0)': KP_test.largeW_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# DP
# Greedy
# Annealing
# Exact Z
# Large W (T=0)
# Large W (T/=0)

# %%
# max power
power = 12
R = 10**2
d = 6

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
v_ratio_list_name_dict = defaultdict(lambda: list())
limit_list = list()
limit_sat_list_name_dict = defaultdict(lambda: list())

# list of gamma vals and min v/w 
gamma_list = list()
min_v_w_list = list()

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    weight_vec = np.random.randint(1,R+1,nelem)
    value_vec = v_multistrong(weight_vec, R=R,d=d)
    
    # Defining Weight Limit as the average of the weights of 
    # randomly chosen objects
    empt_list = []
    for _ in range(10):
        empt_list.append(np.dot(np.random.randint(0,2,nelem), weight_vec))
    Wlimit = int(np.mean(empt_list))   
    limit_list.append(Wlimit)
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Greedy': KP_init.greedy,
                      'Annealing': KP_init.simann_knapsack,
                      r'Exact $Z$': KP_init.exact_z_algorithm,
                      r'Large $W$ ($T=0$)': KP_init.largeW_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeW_algorithm
                     }    
    
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('---')
        print('---')
        
    # collecting gamma_0 and min v/w values
    gamma_list.append(KP_init.gamma_calc())
    min_v_w_list.append(KP_init.greedy_ratio())
    if verbose:
        print('\n Computed gamma_0 value:',KP_init.gamma_calc())
        print('Computed min value-to-weight ratio:',KP_init.greedy_ratio(), '\n')        
              
    
    for name, algo in algo_name_dict.items():

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()
            
        time_list_name_dict[name].append(time.time()-start_clock)        
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)

        # adding accuracy 
        v_ratio_list_name_dict[name].append(np.dot(soln, value_vec)/true_value)  
        limit_sat_list_name_dict[name].append(np.dot(soln, weight_vec)<Wlimit)  
        if verbose: 
            print('%s 1- |V_soln-V_exact|/V_exact: %.7f' % (name, 1-np.abs(1-np.dot(soln, value_vec)/true_value)))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.7f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.7f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 269.000
# ---
# ---
#
#  Computed gamma_0 value: 1.2409638554216866
# Computed min value-to-weight ratio: 1.2409638554216869
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 262.000
# DP computation time: 0.0006771
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.8897849
# Greedy Weight: 221.000
# Greedy computation time: 0.0000184
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9623656
# Annealing Weight: 258.000
# Annealing computation time: 0.0653021
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 262.000
# Exact $Z$ computation time: 0.0124950
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8333333
# Large $W$ ($T=0$) Weight: 304.000
# Large $W$ ($T=0$) computation time: 0.0009739
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8897849
# Large $W$ ($T\neq0$) Weight: 221.000
# Large $W$ ($T\neq0$) computation time: 0.0144949
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.0985980 sec
#
#
# ## N = 16
# ## Weight Limit: 523.000
# ---
# ---
#
#  Computed gamma_0 value: 1.2409638554216866
# Computed min value-to-weight ratio: 1.2409638554216869
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 522.000
# DP computation time: 0.0026422
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9356955
# Greedy Weight: 473.000
# Greedy computation time: 0.0000279
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9619423
# Annealing Weight: 493.000
# Annealing computation time: 0.0576639
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 522.000
# Exact $Z$ computation time: 0.0512640
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9291339
# Large $W$ ($T=0$) Weight: 556.000
# Large $W$ ($T=0$) computation time: 0.0011058
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9356955
# Large $W$ ($T\neq0$) Weight: 473.000
# Large $W$ ($T\neq0$) computation time: 0.0310831
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.2446408 sec
#
#
# ## N = 32
# ## Weight Limit: 882.000
# ---
# ---
#
#  Computed gamma_0 value: 1.2666666666666666
# Computed min value-to-weight ratio: 1.2666666666666666
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 882.000
# DP computation time: 0.0094340
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9662261
# Greedy Weight: 836.000
# Greedy computation time: 0.0000629
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9280470
# Annealing Weight: 864.000
# Annealing computation time: 0.0639622
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9992658
# Exact $Z$ Weight: 881.000
# Exact $Z$ computation time: 0.2029083
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8964758
# Large $W$ ($T=0$) Weight: 761.000
# Large $W$ ($T=0$) computation time: 0.0011909
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8964758
# Large $W$ ($T\neq0$) Weight: 761.000
# Large $W$ ($T\neq0$) computation time: 0.0519052
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.5772650 sec
#
#
# ## N = 64
# ## Weight Limit: 1720.000
# ---
# ---
#
#  Computed gamma_0 value: 1.3125
# Computed min value-to-weight ratio: 1.3125
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1720.000
# DP computation time: 0.0360792
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9970696
# Greedy Weight: 1712.000
# Greedy computation time: 0.0000939
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9120879
# Annealing Weight: 1720.000
# Annealing computation time: 0.0669792
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9996337
# Exact $Z$ Weight: 1719.000
# Exact $Z$ computation time: 0.7823131
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9970696
# Large $W$ ($T=0$) Weight: 1712.000
# Large $W$ ($T=0$) computation time: 0.0011969
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9069597
# Large $W$ ($T\neq0$) Weight: 1526.000
# Large $W$ ($T\neq0$) computation time: 0.0913939
# ---
# Done with Round #4!
# Total elapsed ime so far: 1.5581520 sec
#
#
# ## N = 128
# ## Weight Limit: 3181.000
# ---
# ---
#
#  Computed gamma_0 value: 1.32258064516129
# Computed min value-to-weight ratio: 1.3225806451612903
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 3181.000
# DP computation time: 0.1348267
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9880563
# Greedy Weight: 3129.000
# Greedy computation time: 0.0001988
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9017530
# Annealing Weight: 3181.000
# Annealing computation time: 0.0739150
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9998074
# Exact $Z$ Weight: 3180.000
# Exact $Z$ computation time: 2.9324188
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9803506
# Large $W$ ($T=0$) Weight: 3253.000
# Large $W$ ($T=0$) computation time: 0.0012810
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9250626
# Large $W$ ($T\neq0$) Weight: 2882.000
# Large $W$ ($T\neq0$) computation time: 0.2028589
# ---
# Done with Round #5!
# Total elapsed ime so far: 4.9067459 sec
#
#
# ## N = 256
# ## Weight Limit: 6376.000
# ---
# ---
#
#  Computed gamma_0 value: 1.32258064516129
# Computed min value-to-weight ratio: 1.3225806451612903
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 6376.000
# DP computation time: 0.5457990
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9944800
# Greedy Weight: 6329.000
# Greedy computation time: 0.0004001
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9031571
# Annealing Weight: 6376.000
# Annealing computation time: 0.0788789
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 6376.000
# Exact $Z$ computation time: 11.7626681
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9816967
# Large $W$ ($T=0$) Weight: 6515.000
# Large $W$ ($T=0$) computation time: 0.0014391
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9151656
# Large $W$ ($T\neq0$) Weight: 5710.000
# Large $W$ ($T\neq0$) computation time: 0.3780019
# ---
# Done with Round #6!
# Total elapsed ime so far: 17.6782119 sec
#
#
# ## N = 512
# ## Weight Limit: 12638.000
# ---
# ---
#
#  Computed gamma_0 value: 1.32258064516129
# Computed min value-to-weight ratio: 1.3225806451612903
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 12638.000
# DP computation time: 2.1948848
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9987408
# Greedy Weight: 12612.000
# Greedy computation time: 0.0007932
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.8750484
# Annealing Weight: 12638.000
# Annealing computation time: 0.0944061
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9999516
# Exact $Z$ Weight: 12637.000
# Exact $Z$ computation time: 46.4660311
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9893452
# Large $W$ ($T=0$) Weight: 12798.000
# Large $W$ ($T=0$) computation time: 0.0014379
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9393646
# Large $W$ ($T\neq0$) Weight: 11686.000
# Large $W$ ($T\neq0$) computation time: 0.7779357
# ---
# Done with Round #7!
# Total elapsed ime so far: 67.2194138 sec
#
#
# ## N = 1024
# ## Weight Limit: 25525.000
# ---
# ---
#
#  Computed gamma_0 value: 1.3174603174603172
# Computed min value-to-weight ratio: 1.3174603174603174
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 25525.000
# DP computation time: 8.9049041
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9983118
# Greedy Weight: 25465.000
# Greedy computation time: 0.0016072
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.8753165
# Annealing Weight: 25525.000
# Annealing computation time: 0.1108241
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9997106
# Exact $Z$ Weight: 25523.000
# Exact $Z$ computation time: 187.7110360
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9956831
# Large $W$ ($T=0$) Weight: 25654.000
# Large $W$ ($T=0$) computation time: 0.0017061
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9172796
# Large $W$ ($T\neq0$) Weight: 22925.000
# Large $W$ ($T\neq0$) computation time: 1.7334139
# ---
# Done with Round #8!
# Total elapsed ime so far: 265.6916151 sec
#
#
# ## N = 2048
# ## Weight Limit: 51045.000
# ---
# ---
#
#  Computed gamma_0 value: 1.3125
# Computed min value-to-weight ratio: 1.3125
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 51045.000
# DP computation time: 35.7854307
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9999034
# Greedy Weight: 51037.000
# Greedy computation time: 0.0031080
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.8849798
# Annealing Weight: 51045.000
# Annealing computation time: 0.1377468
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 0.9996259
# Exact $Z$ Weight: 51044.000
# Exact $Z$ computation time: 2752.8545809
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9948343
# Large $W$ ($T=0$) Weight: 50717.000
# Large $W$ ($T=0$) computation time: 0.0028679
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9155875
# Large $W$ ($T\neq0$) Weight: 45751.000
# Large $W$ ($T\neq0$) computation time: 3.5900631
# ---
# Done with Round #9!
# Total elapsed ime so far: 3058.0813119 sec

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                    'DP': 's',  
                 'Greedy': 'o',
                 'Annealing': '^',
                r'Exact $Z$': 'h',
                r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                    'DP': 'blue',  
                 'Greedy': 'green',
                 'Annealing': 'darkorange' ,
                r'Exact $Z$': 'gold',
                r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'slategrey'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, v_ratio in v_ratio_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, 1-np.abs(1-np.array(v_ratio)), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in v_ratio_list_name_dict.items():
    v_ratio = v_ratio_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]

    plt.plot([1-np.abs(1-v_ratio)], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45)
plt.yscale('log')
plt.xticks(fontsize = 22, rotation = -45)
plt.yticks(fontsize = 22)
plt.xlabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (0.4, 0.5), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_vratio_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ## Tabulated Results for $N = 2048$
#
# Here we tabulate the performance results for all algorithms applied to the multi-strong instance with N=2048 items.

# %%
# testing 
algo_name_list = ['DP','Greedy','Annealing', r'Exact $Z$', r'Large $W$ ($T=0$)', r'Large $W$ ($T\neq0$)']

# defining empty results dictionary
results_name_dict = {'runtime': ['runtime']+[0]*6,
                    'error': ['error']+[0]*6,}

# %%
for j in range(6):
    # name of algorithm
    name = algo_name_list[j]
    
    # calculating accuracy and runtime
    v_ratio_val, runtime = v_ratio_list_name_dict[name][-1], time_list_name_dict[name][-1]
    
    # filling in error and runtime values
    results_name_dict['error'][j+1] = np.abs(1-v_ratio_val)
    results_name_dict['runtime'][j+1] = runtime

# %%
from tabulate import tabulate
# creating table of results
tabular_results = []
for k, v in results_name_dict.items():
    tabular_results.append(v) 

print(tabulate(tabular_results, ["", "DP", "Greedy", "Annealing", "Exact Z", "T=0", "T/=0"], tablefmt="grid"))
# Out:
# +---------+---------+-------------+-------------+----------------+------------+-----------+
# |         |      DP |      Greedy |   Annealing |        Exact Z |        T=0 |      T/=0 |
# +=========+=========+=============+=============+================+============+===========+
# | runtime | 35.7854 | 0.00310802  |    0.137747 | 2752.85        | 0.00286794 | 3.59006   |
# +---------+---------+-------------+-------------+----------------+------------+-----------+
# | error   |  0      | 9.65542e-05 |    0.11502  |    0.000374148 | 0.00516565 | 0.0844125 |
# +---------+---------+-------------+-------------+----------------+------------+-----------+

# %% [markdown]
# ## Averag Normed Ratio Difference
#
# The normed ratio difference is defined as
#
# \begin{equation}
#     \text{norm. ratio diff.} = \frac{|\gamma_0 - v_\alpha/w_\alpha|}{\gamma_0},
#     \label{eq:ratio_diff}
# \end{equation}
#
# where $\gamma_0$ is determined from the zero-temperature algorithm and $v_{\alpha}/w_{\alpha}$ is the minimum ratio determined from the standard greedy algorithm. We compute the average of the normed ratio differences for all of the $N$ in the above plots.

# %%
# array conversion
gamma_array, min_v_w_array  = np.array(gamma_list), np.array(min_v_w_list)
# computing normed ratio difference
print('Average of Norm. Ratio. Diff: ', np.mean(np.abs(gamma_list - min_v_w_list)/gamma_list))
# Out:
# Average of Norm. Ratio. Diff:  1.1445114764417863e-16
