# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
from KP import KnapsackProblem

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

import time

# %% [markdown]
# ## Algorithm Comparisons
#
# Notebook code for comparing the time and accuracy of various algorithms to solve the 0-1 Knapsack problem.
#
# Compared algorithms
#
# - **Dynamical Programming Solution:**(`knapsack_dpV`)  Standard iterative solution to the problem which involves storing sub-problem solutions in matrix elements
#
# - **Greedy Algorithm:**(`greedy`)  Algorithm based on computing the ratio of weights to volumes for each object and filling in the collection until the max weight is reached.
#
# - **Simulated Annealing:**(`simannl_knapsack`)   Involves representing the system computationally as a statistical physics one and then "annealing" the system to low temperatures.
#
# - **Exact $Z$ Algorithm:**(`exact_z_algorithm`) Algortihm based on computing the exact partition function recursively for a particular temperature
#
# - **Large W Algorithm ($T=0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T=0$
#
# - **Large W Algorithm ($T\neq0$):**(`largeW_algorithm`)  Algorithm based on statistical physics representation of the system at $T\neq0$

# %% [markdown]
# ### Main Calculation
#
# We now investigate how these accuracies vary as we change the number of items. We will ignore the brute force algorithm since it is so slow and take the dynamical programming solution to be our baseline of comparison (because it is exact).

# %% [markdown]
# ### Hard Instance: Multiple Strongly Correlated Instance
#
# In [1], Pisinger identifies hard four additional difficult instances of the knapsack problem. One such instance is the "multiply strongly correlated instance"  consisting of a combination of two sets of strongly correlated instances. The instnaces that have values that are related to weights through $v = w + k_i$ where $k_i$ for $i=1, 2$ is different for each instance.
#
# In particular the instances are generated as follows: The weights of $N$ items are randomly distributed in $[1, R]$. If the weight $w_j$ is divisible by a chosen $d$, we set the value $v_j = w_j + k_1$, otherwise we set it to $v_j = w_j + k_2$.
#
# Pisinger chose the values $d=6$, $k_1 = 3R/10$, and $k_2 = 2R/10$.  We will use this form of the knapsack problem to outline the performances of various algorithms including the algorithms outlined in the adjoining paper.
#
# [1] Pisinger, D. (2005). Where are the hard knapsack problems?. *Computers & Operations Research*, 32(9), 2271-2284.
#
# http://cic.tju.edu.cn/faculty/gongxj/course/algorithm/doc/2005-Wherearethehardknapsackproblems.pdf

# %%
# defining multi strong instance

def v_multistrong(w, R, d):

    """
    w: list of weights
    m: end point of multiplier range
    R: parameter for generating instances
    d: divisor to determine which strongly correlated factor to choose
    """

    k1, k2 = 3*R/10, 2*R/10

    v = list()
    for welem in w:
        if welem % d == 0:
            v.append(int(welem + k1))
        else:
            v.append(int(welem+k2))
            
    return np.array(v)

# %%
# test instance
KP_test = KnapsackProblem(weights = [1], values = [1], limit = 1)

# dictionary of algorithm names and functions
algo_name_dict = {'DP': KP_test.knapsack01_dpV,
                  'Greedy': KP_test.greedy,
                  'Annealing': KP_test.simann_knapsack,
                  'Exact Z': KP_test.exact_z_algorithm,
                  'Large W (T=0)': KP_test.largeW_algorithm,
                 'Large W (T/=0)': KP_test.largeW_algorithm}


for k, v in algo_name_dict.items():
    print(k)
# Out:
# DP
# Greedy
# Annealing
# Exact Z
# Large W (T=0)
# Large W (T/=0)

# %%
# max power
power = 13
R = 10**2
d = 6

# print intermediate results
verbose = True

# number of elements
nelem_list = [2**k for k in range(3, power)]

# defining default dictionaries
time_list_name_dict = defaultdict(lambda: list())
accuracy_list_name_dict = defaultdict(lambda: list())

# list of degeneracies
degeneracy_list = list()
correlation_list = list()
W_norm_list = list()

# list of gamma vals and min v/w 
gamma_list = list()
min_v_w_list = list()

# start clock
start_clock0 = time.time()

for m in range(len(nelem_list)):
    
    # getting element
    nelem = nelem_list[m]
    
    # set seed
    np.random.seed(42)

    # Randomly choose the weight of each object
    weight_vec = np.random.randint(1,R+1,nelem)
    value_vec = v_multistrong(weight_vec, R=R,d=d)
    
    # Defining weight limit
    Wlimit = int(np.sum(weight_vec)/(2*np.sqrt(nelem)))  
    W_norm_list.append(Wlimit/np.mean(weight_vec))         
    
    # knapsack instance
    KP_init = KnapsackProblem(weights = weight_vec, values = value_vec, limit = Wlimit)
    
    # dictionary of algorithm names and functions
    algo_name_dict = {'DP': KP_init.knapsack01_dpV,
                      'Greedy': KP_init.greedy,
                      'Annealing': KP_init.simann_knapsack,
                      r'Exact $Z$': KP_init.exact_z_algorithm,
                      r'Large $W$ ($T=0$)': KP_init.largeW_algorithm,
                     r'Large $W$ ($T\neq0$)': KP_init.largeW_algorithm
                     }    
    
    # degeneracy and correlation
    degeneracy_list.append(np.mean(list(Counter(weight_vec).values())))
    correlation_list.append(np.corrcoef(weight_vec, value_vec)[0,1])
    
    if verbose:
        print('## N = %s' % str(nelem))
        print('## Weight Limit: %.3f' % Wlimit)
        print('## Weight Limit/Avg Weight: %.3f' % (Wlimit/np.mean(weight_vec)))
        
        # average number of copies of each item
#         print('## Average degeneracy: %.3f' % np.mean(list(Counter(weight_vec).values()))  )
        print('## N_eff: %.3f' % (nelem/np.mean(list(Counter(weight_vec).values()))) )        
        print('## Correlation between values and weights: %.3f' % np.corrcoef(weight_vec, value_vec)[0,1])
        print('---')
        print('---')
        
    # collecting gamma_0 and min v/w values
    gamma_list.append(KP_init.gamma_calc())
    min_v_w_list.append(KP_init.greedy_ratio())
    
    if verbose:
        print('\nComputed gamma_0 value:',KP_init.gamma_calc())
        print('Computed min value-to-weight ratio:',KP_init.greedy_ratio(), '\n')
              
    for name, algo in algo_name_dict.items():

        # finding solution and computing time    
        start_clock = time.time()
        if name == r'Large $W$ ($T\neq0$)':
            soln = algo(T=1.0)
        else:    
            soln = algo()      
    
        if name == 'DP':
            true_value = np.dot(soln, value_vec)
            
        # getting runtime and accuracy
        time_list_name_dict[name].append(time.time()-start_clock)     
        accuracy_list_name_dict[name].append(1-np.abs(1-np.dot(soln, value_vec)/true_value)) 
        
        if verbose: 
            print('%s 1- |V_soln-V_exact|/V_exact: %.7f' % (name, accuracy_list_name_dict[name][-1]))
            print('%s Weight: %.3f' % (name, np.dot(soln, weight_vec)))
            print('%s computation time: %.7f' % (name, time_list_name_dict[name][-1]))
            print('---')
            
    if verbose: 
        print('Done with Round #%i!' % (m+1))
        print('Total elapsed ime so far: %.7f sec' % (time.time()-start_clock0))
        print('')
        print('')
# Out:
# ## N = 8
# ## Weight Limit: 85.000
# ## Weight Limit/Avg Weight: 1.405
# ## N_eff: 8.000
# ## Correlation between values and weights: 0.993
# ---
# ---
#
# Computed gamma_0 value: 1.4166666666666665
# Computed min value-to-weight ratio: 1.4166666666666667
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 82.000
# DP computation time: 0.0002100
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.6229508
# Greedy Weight: 36.000
# Greedy computation time: 0.0000179
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.9508197
# Annealing Weight: 76.000
# Annealing computation time: 0.1242299
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 82.000
# Exact $Z$ computation time: 0.0017247
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.5409836
# Large $W$ ($T=0$) Weight: 108.000
# Large $W$ ($T=0$) computation time: 0.0009868
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.6229508
# Large $W$ ($T\neq0$) Weight: 36.000
# Large $W$ ($T\neq0$) computation time: 0.0169840
# ---
# Done with Round #1!
# Total elapsed ime so far: 0.1494510 sec
#
#
# ## N = 16
# ## Weight Limit: 115.000
# ## Weight Limit/Avg Weight: 1.991
# ## N_eff: 15.000
# ## Correlation between values and weights: 0.994
# ---
# ---
#
# Computed gamma_0 value: 1.416666666666667
# Computed min value-to-weight ratio: 1.4166666666666667
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 115.000
# DP computation time: 0.0005012
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.8666667
# Greedy Weight: 85.000
# Greedy computation time: 0.0000248
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.7600000
# Annealing Weight: 111.000
# Annealing computation time: 0.1698551
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 115.000
# Exact $Z$ computation time: 0.0069599
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8666667
# Large $W$ ($T=0$) Weight: 85.000
# Large $W$ ($T=0$) computation time: 0.0009711
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8666667
# Large $W$ ($T\neq0$) Weight: 85.000
# Large $W$ ($T\neq0$) computation time: 0.0294380
# ---
# Done with Round #2!
# Total elapsed ime so far: 0.3594723 sec
#
#
# ## N = 32
# ## Weight Limit: 150.000
# ## Weight Limit/Avg Weight: 2.814
# ## N_eff: 27.000
# ## Correlation between values and weights: 0.994
# ---
# ---
#
# Computed gamma_0 value: 1.9090909090909092
# Computed min value-to-weight ratio: 1.9090909090909092
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 147.000
# DP computation time: 0.0013289
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9798271
# Greedy Weight: 140.000
# Greedy computation time: 0.0000472
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.6628242
# Annealing Weight: 150.000
# Annealing computation time: 0.2296569
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 147.000
# Exact $Z$ computation time: 0.0228281
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8587896
# Large $W$ ($T=0$) Weight: 118.000
# Large $W$ ($T=0$) computation time: 0.0009789
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8991354
# Large $W$ ($T\neq0$) Weight: 162.000
# Large $W$ ($T\neq0$) computation time: 0.0463421
# ---
# Done with Round #3!
# Total elapsed ime so far: 0.6630292 sec
#
#
# ## N = 64
# ## Weight Limit: 205.000
# ## Weight Limit/Avg Weight: 3.998
# ## N_eff: 45.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 1.952380952380952
# Computed min value-to-weight ratio: 1.9523809523809523
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 204.000
# DP computation time: 0.0039570
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9574468
# Greedy Weight: 190.000
# Greedy computation time: 0.0001030
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.6294326
# Annealing Weight: 205.000
# Annealing computation time: 0.2572927
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 204.000
# Exact $Z$ computation time: 0.0706728
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9698582
# Large $W$ ($T=0$) Weight: 211.000
# Large $W$ ($T=0$) computation time: 0.0010171
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8120567
# Large $W$ ($T\neq0$) Weight: 148.000
# Large $W$ ($T\neq0$) computation time: 0.0981851
# ---
# Done with Round #4!
# Total elapsed ime so far: 1.0969973 sec
#
#
# ## N = 128
# ## Weight Limit: 281.000
# ## Weight Limit/Avg Weight: 5.646
# ## N_eff: 70.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 2.0
# Computed min value-to-weight ratio: 2.0
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 277.000
# DP computation time: 0.0108562
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 1.0000000
# Greedy Weight: 277.000
# Greedy computation time: 0.0001791
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.5728155
# Annealing Weight: 281.000
# Annealing computation time: 0.3079848
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 277.000
# Exact $Z$ computation time: 0.2123222
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 1.0000000
# Large $W$ ($T=0$) Weight: 277.000
# Large $W$ ($T=0$) computation time: 0.0013340
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 1.0000000
# Large $W$ ($T\neq0$) Weight: 277.000
# Large $W$ ($T\neq0$) computation time: 0.1802719
# ---
# Done with Round #5!
# Total elapsed ime so far: 1.8129911 sec
#
#
# ## N = 256
# ## Weight Limit: 403.000
# ## Weight Limit/Avg Weight: 7.991
# ## N_eff: 94.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 2.25
# Computed min value-to-weight ratio: 2.25
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 403.000
# DP computation time: 0.0325589
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9966510
# Greedy Weight: 398.000
# Greedy computation time: 0.0003831
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.4440723
# Annealing Weight: 403.000
# Annealing computation time: 0.5636942
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 403.000
# Exact $Z$ computation time: 0.8070452
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9604823
# Large $W$ ($T=0$) Weight: 374.000
# Large $W$ ($T=0$) computation time: 0.0014510
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9604823
# Large $W$ ($T\neq0$) Weight: 374.000
# Large $W$ ($T\neq0$) computation time: 0.3266230
# ---
# Done with Round #6!
# Total elapsed ime so far: 3.5492351 sec
#
#
# ## N = 512
# ## Weight Limit: 566.000
# ## Weight Limit/Avg Weight: 11.294
# ## N_eff: 99.000
# ## Correlation between values and weights: 0.991
# ---
# ---
#
# Computed gamma_0 value: 2.333333333333334
# Computed min value-to-weight ratio: 2.3333333333333335
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 566.000
# DP computation time: 0.0956070
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9906915
# Greedy Weight: 555.000
# Greedy computation time: 0.0007470
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.3794326
# Annealing Weight: 566.000
# Annealing computation time: 1.1718352
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 566.000
# Exact $Z$ computation time: 1.8829770
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9596631
# Large $W$ ($T=0$) Weight: 525.000
# Large $W$ ($T=0$) computation time: 0.0014980
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8843085
# Large $W$ ($T\neq0$) Weight: 455.000
# Large $W$ ($T\neq0$) computation time: 0.7852569
# ---
# Done with Round #7!
# Total elapsed ime so far: 7.4926412 sec
#
#
# ## N = 1024
# ## Weight Limit: 801.000
# ## Weight Limit/Avg Weight: 15.986
# ## N_eff: 100.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 2.666666666666667
# Computed min value-to-weight ratio: 2.6666666666666665
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 801.000
# DP computation time: 0.2737250
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9939743
# Greedy Weight: 789.000
# Greedy computation time: 0.0014789
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.3070392
# Annealing Weight: 801.000
# Annealing computation time: 2.2175090
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 801.000
# Exact $Z$ computation time: 5.7842371
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9676801
# Large $W$ ($T=0$) Weight: 753.000
# Large $W$ ($T=0$) computation time: 0.0017490
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9676801
# Large $W$ ($T\neq0$) Weight: 753.000
# Large $W$ ($T\neq0$) computation time: 1.4119160
# ---
# Done with Round #8!
# Total elapsed ime so far: 17.1917970 sec
#
#
# ## N = 2048
# ## Weight Limit: 1134.000
# ## Weight Limit/Avg Weight: 22.621
# ## N_eff: 100.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 3.2222222222222223
# Computed min value-to-weight ratio: 3.2222222222222223
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1134.000
# DP computation time: 0.7839043
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9972290
# Greedy Weight: 1128.000
# Greedy computation time: 0.0029528
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.2864565
# Annealing Weight: 1134.000
# Annealing computation time: 3.5783639
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 1134.000
# Exact $Z$ computation time: 16.5571880
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.9570488
# Large $W$ ($T=0$) Weight: 1056.000
# Large $W$ ($T=0$) computation time: 0.0022521
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.9570488
# Large $W$ ($T\neq0$) Weight: 1056.000
# Large $W$ ($T\neq0$) computation time: 3.0495160
# ---
# Done with Round #9!
# Total elapsed ime so far: 41.1795490 sec
#
#
# ## N = 4096
# ## Weight Limit: 1586.000
# ## Weight Limit/Avg Weight: 31.988
# ## N_eff: 100.000
# ## Correlation between values and weights: 0.992
# ---
# ---
#
# Computed gamma_0 value: 3.5
# Computed min value-to-weight ratio: 3.5
#
# DP 1- |V_soln-V_exact|/V_exact: 1.0000000
# DP Weight: 1586.000
# DP computation time: 2.2252181
# ---
# Greedy 1- |V_soln-V_exact|/V_exact: 0.9982175
# Greedy Weight: 1580.000
# Greedy computation time: 0.0060191
# ---
# Stopping annealing because error tolerance was reached
# Annealing 1- |V_soln-V_exact|/V_exact: 0.2736185
# Annealing Weight: 1586.000
# Annealing computation time: 5.9022791
# ---
# Exact $Z$ 1- |V_soln-V_exact|/V_exact: 1.0000000
# Exact $Z$ Weight: 1586.000
# Exact $Z$ computation time: 46.8028278
# ---
# Large $W$ ($T=0$) 1- |V_soln-V_exact|/V_exact: 0.8172906
# Large $W$ ($T=0$) Weight: 1116.000
# Large $W$ ($T=0$) computation time: 0.0033429
# ---
# Large $W$ ($T\neq0$) 1- |V_soln-V_exact|/V_exact: 0.8172906
# Large $W$ ($T\neq0$) Weight: 1116.000
# Large $W$ ($T\neq0$) computation time: 7.0691671
# ---
# Done with Round #10!
# Total elapsed ime so far: 103.2127790 sec

# %%
neff_unique = np.array(nelem_list)/np.array(degeneracy_list)
neff_unique
# Out:
# array([  8.,  15.,  27.,  45.,  70.,  94.,  99., 100., 100., 100.])

# %%
np.array(correlation_list)
# Out:
# array([0.99332937, 0.99410832, 0.99380803, 0.99179919, 0.99154447,
#        0.99198891, 0.99135013, 0.99197642, 0.9921551 , 0.99211463])

# %%
plt.plot(nelem_list, neff_unique, color = 'salmon', markersize = 10, marker = 'o')

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xscale('log')
plt.xticks(fontsize = 15)
plt.axhline(y=100, color = 'k', linestyle = 'dashed', linewidth = 0.25)
plt.yticks(fontsize = 15)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$N_{eff}$', fontsize = 24, labelpad=10.0)
plt.show()

# %%
np.array(W_norm_list)
# Out:
# array([ 1.40495868,  1.99134199,  2.81359906,  3.99756246,  5.64646782,
#         7.9907056 , 11.2944111 , 15.98627894, 22.62057681, 31.98833969])

# %%
plt.plot(nelem_list, np.array(W_norm_list), markersize = 10, marker = 'o')

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xscale('log')
plt.xticks(fontsize = 15)
# plt.axhline(y=100, color = 'k', linestyle = 'dashed', linewidth = 0.25)
plt.yticks(fontsize = 15)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$W/\bar{w}$', fontsize = 24, labelpad=10.0)
plt.show()

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Accuracy vs $N$

# %%
# dictionary of algorithm names and functions
marker_name_dict = {
                    'DP': 's',  
                 'Greedy': 'o',
                 'Annealing': '^',
                r'Exact $Z$': 'h',
                r'Large $W$ ($T=0$)': 'P',
                r'Large $W$ ($T\neq0$)':'p'}

# dictionary of algorithm names and functions
color_name_dict = {
                    'DP': 'blue',  
                 'Greedy': 'green',
                 'Annealing': 'darkorange' ,
                r'Exact $Z$': 'gold',
                r'Large $W$ ($T=0$)': 'red',
                r'Large $W$ ($T\neq0$)':'slategrey'}

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, accuracy_ in accuracy_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(accuracy_), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'Accuracy', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, accuracy_ in accuracy_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(accuracy_), marker = marker_name_dict[name], color = color_name_dict[name], linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xscale('log')
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.ylabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20.0)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/vratio_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs $N$

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45, linestyle = '--')
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %%
plt.figure(figsize = (8,6))

ax = plt.subplot(111)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

for name, time_ in time_list_name_dict.items():

    nums = nelem_list
    plt.plot(nums, np.array(time_), marker_name_dict[name], color = color_name_dict[name],linestyle = '-', label = r'%s' % name, markersize = 15)

plt.grid(alpha = 0.45)
plt.xlabel(r'$N$', fontsize = 24, labelpad=20.0)
plt.xticks(fontsize = 22)
plt.yticks(fontsize = 22)
plt.yscale("log")
plt.xscale("log")
plt.ylabel(r'Time (sec)', fontsize = 24, labelpad=20.0)
plt.legend(loc = (.01,.6), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_num_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ### Time vs Accuracy

# %%
## accuracy-time scatter plot

plt.figure(figsize = (8,6))

ax = plt.subplot(111)

for name, _ in accuracy_list_name_dict.items():
    accuracy_ = accuracy_list_name_dict[name][-1]
    time_ = time_list_name_dict[name][-1]

    plt.plot([accuracy_], [time_], marker_name_dict[name], color = color_name_dict[name], label = r'%s' % name, markersize = 18)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.grid(alpha = 0.45)
plt.yscale('log')
plt.xticks(fontsize = 22, rotation = -45)
plt.yticks(fontsize = 22)
plt.xlabel(r'$1-|V-V_{exact}|/V_{exact}$', fontsize = 24, labelpad=20)
plt.ylabel(r'Time (sec)', fontsize = 24)
plt.legend(loc = (0.4, 0.5), fontsize = 15)

# plt.savefig('/Users/mobolajiwilliams/Dropbox/0Tex_Files_Mac/2020_largeN_knapsack_problem/LaTeX_JStatPhys/time_vs_vratio_multi_strong.png', dpi = 100, bbox_inches='tight' )

plt.show()

# %% [markdown]
# ## Tabulated Results for $N = 2048$
#
# Here we tabulate the performance results for all algorithms applied to the multi-strong instance with N=2048 items.

# %%
# testing 
algo_name_list = ['DP','Greedy','Annealing', r'Exact $Z$', r'Large $W$ ($T=0$)', r'Large $W$ ($T\neq0$)']

# defining empty results dictionary
results_name_dict = {'runtime': ['runtime']+[0]*6,
                    'error': ['error']+[0]*6,}

# %%
for j in range(6):
    # name of algorithm
    name = algo_name_list[j]
    
    # calculating accuracy and runtime
    accuracy, runtime = accuracy_list_name_dict[name][-1], time_list_name_dict[name][-1]
    
    # filling in error and runtime values
    results_name_dict['error'][j+1] = 1-accuracy
    results_name_dict['runtime'][j+1] = runtime

# %%
from tabulate import tabulate
# creating table of results
tabular_results = []
for k, v in results_name_dict.items():
    tabular_results.append(v) 

print(tabulate(tabular_results, ["", "DP", "Greedy", "Annealing", "Exact Z", "T=0", "T/=0"], tablefmt="grid"))
# Out:
# +---------+---------+-------------+-------------+----------------+------------+-----------+
# |         |      DP |      Greedy |   Annealing |        Exact Z |        T=0 |      T/=0 |
# +=========+=========+=============+=============+================+============+===========+
# | runtime | 35.7854 | 0.00310802  |    0.137747 | 2752.85        | 0.00286794 | 3.59006   |
# +---------+---------+-------------+-------------+----------------+------------+-----------+
# | error   |  0      | 9.65542e-05 |    0.11502  |    0.000374148 | 0.00516565 | 0.0844125 |
# +---------+---------+-------------+-------------+----------------+------------+-----------+

# %% [markdown]
# ## Averag Normed Ratio Difference
#
# The normed ratio difference is defined as
#
# \begin{equation}
#     \text{norm. ratio diff.} = \frac{|\gamma_0 - v_\alpha/w_\alpha|}{\gamma_0},
#     \label{eq:ratio_diff}
# \end{equation}
#
# where $\gamma_0$ is determined from the zero-temperature algorithm and $v_{\alpha}/w_{\alpha}$ is the minimum ratio determined from the standard greedy algorithm. We compute the average of the normed ratio differences for all of the $N$ in the above plots.

# %%
# array conversion
gamma_array, min_v_w_array  = np.array(gamma_list), np.array(min_v_w_list)
# computing normed ratio difference
print('Average of Norm. Ratio. Diff: ', np.mean(np.abs(gamma_list - min_v_w_list)/gamma_list))
# Out:
# Average of Norm. Ratio. Diff:  1.1445114764417863e-16
